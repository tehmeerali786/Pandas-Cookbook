# %% [markdown]
# # Chapter 7: Grouping for Aggregation, Filtration and Transformation
# ## Recipes
# * [Defining an aggregation](#Defining-an-aggregation)
# * [Grouping and aggregating with multiple columns and functions](#Grouping-and-aggregating-with-multiple-columns-and-functions)
# * [Removing the MultiIndex after grouping](#Removing-the-MultiIndex-after-grouping)
# * [Customizing an aggregation function](#Customizing-an-aggregation-function)
# * [Customizing aggregating functions with \*args and \*\*kwargs](#Customizing-aggregating-functions-with-*args-and-**kwargs)
# * [Examining the groupby object](#Examining-a-groupby-object)
# * [Filtering for states with a minority majority](#Filtering-for-states-with-a-minority-majority)
# * [Transforming through a weight loss bet](#Transforming-through-a-weight-loss)
# * [Calculating weighted mean SAT scores per state with apply](#Calculating-weighted-mean-SAT-scores-per-state-with-apply)
# * [Grouping by continuous variables](#Grouping-by-continuous-variables)
# * [Counting the total number of flights between cities](#Counting-the-total-number-of-flights-between-cities)
# * [Finding the longest streak of on-time flights](#Finding-the-longest-streak-of-on-time-flights)

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Defining an aggregation

# %%
flights = pd.read_csv('data/flights.csv')

# %%
flights.head()
# Out:
#    MONTH  DAY  WEEKDAY AIRLINE ORG_AIR DEST_AIR  SCHED_DEP  DEP_DELAY  \
# 0      1    1        4      WN     LAX      SLC       1625       58.0
# 1      1    1        4      UA     DEN      IAD        823        7.0
# 2      1    1        4      MQ     DFW      VPS       1305       36.0
# 3      1    1        4      AA     DFW      DCA       1555        7.0
# 4      1    1        4      WN     LAX      MCI       1720       48.0
#
#    AIR_TIME  DIST  SCHED_ARR  ARR_DELAY  DIVERTED  CANCELLED
# 0      94.0   590       1905       65.0         0          0
# 1     154.0  1452       1333      -13.0         0          0
# 2      85.0   641       1453       35.0         0          0
# 3     126.0  1192       1935       -7.0         0          0
# 4     166.0  1363       2225       39.0         0          0

# %%
flights.groupby('AIRLINE')['ARR_DELAY'].agg('mean').head()
# Out:
# AIRLINE
# AA    5.542661
# AS   -0.833333
# B6    8.692593
# DL    0.339691
# EV    7.034580
# Name: ARR_DELAY, dtype: float64

# %%
flights.groupby('AIRLINE').agg({'ARR_DELAY': 'mean'}).head()
# Out:
#          ARR_DELAY
# AIRLINE
# AA        5.542661
# AS       -0.833333
# B6        8.692593
# DL        0.339691
# EV        7.034580

# %%
flights.groupby('AIRLINE')['ARR_DELAY'].agg(np.mean).head()
# Out:
# AIRLINE
# AA    5.542661
# AS   -0.833333
# B6    8.692593
# DL    0.339691
# EV    7.034580
# Name: ARR_DELAY, dtype: float64

# %% [markdown]
# # How it works ......

# %%
grouped = flights.groupby('AIRLINE')
type(grouped)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
flights.groupby('AIRLINE')['ARR_DELAY'].mean().head()
# Out:
# AIRLINE
# AA    5.542661
# AS   -0.833333
# B6    8.692593
# DL    0.339691
# EV    7.034580
# Name: ARR_DELAY, dtype: float64

# %% [markdown]
# ## There's more ........

# %%
flights.groupby('AIRLINE')['ARR_DELAY'].agg(np.sqrt)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py:844: RuntimeWarning: invalid value encountered in sqrt
#   f = lambda x: func(x, *args, **kwargs)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\generic.py:907: RuntimeWarning: invalid value encountered in sqrt
#   output = func(group, *args, **kwargs)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\ops.py in agg_series(self, obj, func)
#     589         try:
# --> 590             return self._aggregate_series_fast(obj, func)
#     591         except Exception:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\ops.py in _aggregate_series_fast(self, obj, func)
#     609                                           dummy)
# --> 610         result, counts = grouper.get_result()
#     611         return result, counts
#
# pandas/_libs/reduction.pyx in pandas._libs.reduction.SeriesGrouper.get_result()
#
# pandas/_libs/reduction.pyx in pandas._libs.reduction.SeriesGrouper.get_result()
#
# pandas/_libs/reduction.pyx in pandas._libs.reduction._get_result_array()
#
# ValueError: function does not reduce
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\generic.py in aggregate(self, func_or_funcs, *args, **kwargs)
#     775             try:
# --> 776                 return self._python_agg_general(func_or_funcs, *args, **kwargs)
#     777             except Exception:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in _python_agg_general(self, func, *args, **kwargs)
#     849             try:
# --> 850                 result, counts = self.grouper.agg_series(obj, f)
#     851                 output[name] = self._try_cast(result, obj, numeric_only=True)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\ops.py in agg_series(self, obj, func)
#     591         except Exception:
# --> 592             return self._aggregate_series_pure_python(obj, func)
#     593
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\ops.py in _aggregate_series_pure_python(self, obj, func)
#     625                 if (isinstance(res, (Series, Index, np.ndarray))):
# --> 626                     raise ValueError('Function does not reduce')
#     627                 result = np.empty(ngroups, dtype='O')
#
# ValueError: Function does not reduce
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# <ipython-input-10-dd6f98cc3f76> in <module>
# ----> 1 flights.groupby('AIRLINE')['ARR_DELAY'].agg(np.sqrt)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\generic.py in aggregate(self, func_or_funcs, *args, **kwargs)
#     776                 return self._python_agg_general(func_or_funcs, *args, **kwargs)
#     777             except Exception:
# --> 778                 result = self._aggregate_named(func_or_funcs, *args, **kwargs)
#     779
#     780             index = Index(sorted(result), name=self.grouper.names[0])
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\generic.py in _aggregate_named(self, func, *args, **kwargs)
#     907             output = func(group, *args, **kwargs)
#     908             if isinstance(output, (Series, Index, np.ndarray)):
# --> 909                 raise Exception('Must produce aggregated value')
#     910             result[name] = self._try_cast(output, group)
#     911
#
# Exception: Must produce aggregated value

# %% [markdown]
# # Grouping and aggregating with multiple columns and functions

# %%
flights = pd.read_csv('data/flights.csv')
flights.head()
# Out:
#    MONTH  DAY  WEEKDAY AIRLINE ORG_AIR DEST_AIR  SCHED_DEP  DEP_DELAY  \
# 0      1    1        4      WN     LAX      SLC       1625       58.0
# 1      1    1        4      UA     DEN      IAD        823        7.0
# 2      1    1        4      MQ     DFW      VPS       1305       36.0
# 3      1    1        4      AA     DFW      DCA       1555        7.0
# 4      1    1        4      WN     LAX      MCI       1720       48.0
#
#    AIR_TIME  DIST  SCHED_ARR  ARR_DELAY  DIVERTED  CANCELLED
# 0      94.0   590       1905       65.0         0          0
# 1     154.0  1452       1333      -13.0         0          0
# 2      85.0   641       1453       35.0         0          0
# 3     126.0  1192       1935       -7.0         0          0
# 4     166.0  1363       2225       39.0         0          0

# %%
# The number of cancelled flights for every airline per day weekday
flights.groupby(['AIRLINE', 'WEEKDAY'])['CANCELLED'].agg('sum').head(7)
# Out:
# AIRLINE  WEEKDAY
# AA       1          41
#          2           9
#          3          16
#          4          20
#          5          18
#          6          21
#          7          29
# Name: CANCELLED, dtype: int64

# %%
# Find the number and percentage of cancelled and dirverted flights 
# the number and percentage of cancelled flights and the average and variance of the airtime.

group_cols = ['ORG_AIR', 'DEST_AIR']
agg_dict = {'CANCELLED': ['sum', 'mean', 'size'],
           'AIR_TIME': ['mean', 'var', 'std']}

flights.groupby(group_cols).agg(agg_dict).head()
# flights.groupby(['ORG_AIR', 'DEST_AIR']).agg({'CANCELLED': ['sum', 'mean', 'size'],
#           'AIR_TIME': ['mean', 'var']}).head()
# Out:
#                  CANCELLED              AIR_TIME
#                        sum mean size        mean        var       std
# ORG_AIR DEST_AIR
# ATL     ABE              0  0.0   31   96.387097  45.778495  6.765981
#         ABQ              0  0.0   16  170.500000  87.866667  9.373722
#         ABY              0  0.0   19   28.578947   6.590643  2.567225
#         ACY              0  0.0    6   91.333333  11.466667  3.386247
#         AEX              0  0.0   40   78.725000  47.332692  6.879876

# %% [markdown]
# # Removing the MultiIndex after grouping

# %%
flights = pd.read_csv('data/flights.csv')
flights.head()
# Out:
#    MONTH  DAY  WEEKDAY AIRLINE ORG_AIR DEST_AIR  SCHED_DEP  DEP_DELAY  \
# 0      1    1        4      WN     LAX      SLC       1625       58.0
# 1      1    1        4      UA     DEN      IAD        823        7.0
# 2      1    1        4      MQ     DFW      VPS       1305       36.0
# 3      1    1        4      AA     DFW      DCA       1555        7.0
# 4      1    1        4      WN     LAX      MCI       1720       48.0
#
#    AIR_TIME  DIST  SCHED_ARR  ARR_DELAY  DIVERTED  CANCELLED
# 0      94.0   590       1905       65.0         0          0
# 1     154.0  1452       1333      -13.0         0          0
# 2      85.0   641       1453       35.0         0          0
# 3     126.0  1192       1935       -7.0         0          0
# 4     166.0  1363       2225       39.0         0          0

# %%
airline_info = flights.groupby(['AIRLINE', 'WEEKDAY']).agg({'DIST' : ['sum', 'mean'], 'ARR_DELAY': ['min', 'max']}).astype(int)

# %%
airline_info.head(10)
# Out:
#                     DIST       ARR_DELAY
#                      sum  mean       min  max
# AIRLINE WEEKDAY
# AA      1        1455386  1139       -60  551
#         2        1358256  1107       -52  725
#         3        1496665  1117       -45  473
#         4        1452394  1089       -46  349
#         5        1427749  1122       -41  732
#         6        1265340  1124       -50  858
#         7        1461906  1100       -49  626
# AS      1         121478  1029       -28  145
#         2         114681  1081       -38   86
#         3         120150  1044       -45  106

# %%
level0 = airline_info.columns.get_level_values(0)
level0
# Out:
# Index(['DIST', 'DIST', 'ARR_DELAY', 'ARR_DELAY'], dtype='object')

# %%
level1 = airline_info.columns.get_level_values(1)
level1
# Out:
# Index(['sum', 'mean', 'min', 'max'], dtype='object')

# %%
airline_info.columns = level0 + '_' + level1

# %%
airline_info.columns
# Out:
# Index(['DIST_sum', 'DIST_mean', 'ARR_DELAY_min', 'ARR_DELAY_max'], dtype='object')

# %%
airline_info.head(7)
# Out:
#                  DIST_sum  DIST_mean  ARR_DELAY_min  ARR_DELAY_max
# AIRLINE WEEKDAY
# AA      1         1455386       1139            -60            551
#         2         1358256       1107            -52            725
#         3         1496665       1117            -45            473
#         4         1452394       1089            -46            349
#         5         1427749       1122            -41            732
#         6         1265340       1124            -50            858
#         7         1461906       1100            -49            626

# %%
airline_info.reset_index().head(7)
# Out:
#   AIRLINE  WEEKDAY  DIST_sum  DIST_mean  ARR_DELAY_min  ARR_DELAY_max
# 0      AA        1   1455386       1139            -60            551
# 1      AA        2   1358256       1107            -52            725
# 2      AA        3   1496665       1117            -45            473
# 3      AA        4   1452394       1089            -46            349
# 4      AA        5   1427749       1122            -41            732
# 5      AA        6   1265340       1124            -50            858
# 6      AA        7   1461906       1100            -49            626

# %% [markdown]
# ### There's more ........

# %%
flights.groupby(['AIRLINE'], as_index=False)['DIST'].agg('mean').round(0)
# Out:
#    AIRLINE    DIST
# 0       AA  1114.0
# 1       AS  1066.0
# 2       B6  1772.0
# 3       DL   866.0
# 4       EV   460.0
# 5       F9   970.0
# 6       HA  2615.0
# 7       MQ   404.0
# 8       NK  1047.0
# 9       OO   511.0
# 10      UA  1231.0
# 11      US  1181.0
# 12      VX  1240.0
# 13      WN   810.0

# %%
flights.groupby(['AIRLINE'], as_index=False, sort=False)['DIST'].agg('mean')
# Out:
#    AIRLINE         DIST
# 0       WN   809.985626
# 1       UA  1230.918891
# 2       MQ   404.229041
# 3       AA  1114.347865
# 4       F9   969.593014
# 5       EV   460.237453
# 6       OO   511.239375
# 7       NK  1047.428100
# 8       US  1181.226625
# 9       AS  1065.884115
# 10      DL   866.448448
# 11      VX  1240.296073
# 12      B6  1771.882136
# 13      HA  2615.178571

# %% [markdown]
# # Customizing an aggregation function

# %%
college = pd.read_csv('data/college.csv')
college.head()
# Out:
#                                 INSTNM        CITY STABBR  HBCU  MENONLY  \
# 0             Alabama A & M University      Normal     AL   1.0      0.0
# 1  University of Alabama at Birmingham  Birmingham     AL   0.0      0.0
# 2                   Amridge University  Montgomery     AL   0.0      0.0
# 3  University of Alabama in Huntsville  Huntsville     AL   0.0      0.0
# 4             Alabama State University  Montgomery     AL   1.0      0.0
#
#    WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  ...  UGDS_2MOR  \
# 0        0.0         0     424.0     420.0           0.0  ...     0.0000
# 1        0.0         0     570.0     565.0           0.0  ...     0.0368
# 2        0.0         1       NaN       NaN           1.0  ...     0.0000
# 3        0.0         0     595.0     590.0           0.0  ...     0.0172
# 4        0.0         0     425.0     430.0           0.0  ...     0.0098
#
#    UGDS_NRA  UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  \
# 0    0.0059     0.0138    0.0656         1   0.7356    0.8284   0.1049
# 1    0.0179     0.0100    0.2607         1   0.3460    0.5214   0.2422
# 2    0.0000     0.2715    0.4536         1   0.6801    0.7795   0.8540
# 3    0.0332     0.0350    0.2146         1   0.3072    0.4596   0.2640
# 4    0.0243     0.0137    0.0892         1   0.7347    0.7554   0.1270
#
#    MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 0            30300               33888
# 1            39700             21941.5
# 2            40100               23370
# 3            45500               24097
# 4            26600             33118.5
#
# [5 rows x 27 columns]

# %%
college.groupby('STABBR')['UGDS'].agg(['mean', 'std']).round(1).head()
# Out:
#           mean      std
# STABBR
# AK      2493.2   4051.7
# AL      2789.9   4657.9
# AR      1644.1   3142.8
# AS      1276.0      NaN
# AZ      4130.5  14893.6

# %%
def max_deviation(s):
    std_score = (s-s.mean())/s.std()
    return std_score.abs().max()

# %%
college.groupby('STABBR')['UGDS'].agg(max_deviation).round(1).head()
# Out:
# STABBR
# AK    2.6
# AL    5.8
# AR    6.3
# AS    NaN
# AZ    9.9
# Name: UGDS, dtype: float64

# %% [markdown]
# ## There's more .....

# %%
college.groupby('STABBR')['UGDS', 'SATVRMID', 'SATMTMID'].agg([max_deviation, 'mean', 'std']).round(1).head()
# Out:
#                 UGDS                       SATVRMID               \
#        max_deviation    mean      std max_deviation   mean   std
# STABBR
# AK               2.6  2493.2   4051.7           NaN  555.0   NaN
# AL               5.8  2789.9   4657.9           1.6  508.5  54.5
# AR               6.3  1644.1   3142.8           2.2  491.9  48.3
# AS               NaN  1276.0      NaN           NaN    NaN   NaN
# AZ               9.9  4130.5  14893.6           1.9  538.3  28.0
#
#             SATMTMID
#        max_deviation   mean   std
# STABBR
# AK               NaN  503.0   NaN
# AL               1.8  504.3  58.9
# AR               2.3  515.9  38.8
# AS               NaN    NaN   NaN
# AZ               1.4  536.7  39.7

# %%
college.groupby(['STABBR', 'RELAFFIL'])['UGDS', 'SATVRMID', 'SATMTMID'].agg([max_deviation, 'mean', 'std']).round(1).head()
# Out:
#                          UGDS                      SATVRMID               \
#                 max_deviation    mean     std max_deviation   mean   std
# STABBR RELAFFIL
# AK     0                  2.1  3508.9  4539.5           NaN    NaN   NaN
#        1                  1.1   123.3   132.9           NaN  555.0   NaN
# AL     0                  5.2  3248.8  5102.4           1.6  514.9  56.5
#        1                  2.4   979.7   870.8           1.5  498.0  53.0
# AR     0                  5.8  1793.7  3401.6           1.9  481.1  37.9
#
#                      SATMTMID
#                 max_deviation   mean   std
# STABBR RELAFFIL
# AK     0                  NaN    NaN   NaN
#        1                  NaN  503.0   NaN
# AL     0                  1.7  515.8  56.7
#        1                  1.4  485.6  61.4
# AR     0                  2.0  503.6  39.0

# %%
max_deviation.__name__ = 'Max Deviation'

# %%
college.groupby(['STABBR', 'RELAFFIL'])['UGDS', 'SATVRMID', 'SATMTMID']\
                .agg([max_deviation, 'mean', 'std']).round(1).head()
# Out:
#                          UGDS                      SATVRMID               \
#                 Max Deviation    mean     std Max Deviation   mean   std
# STABBR RELAFFIL
# AK     0                  2.1  3508.9  4539.5           NaN    NaN   NaN
#        1                  1.1   123.3   132.9           NaN  555.0   NaN
# AL     0                  5.2  3248.8  5102.4           1.6  514.9  56.5
#        1                  2.4   979.7   870.8           1.5  498.0  53.0
# AR     0                  5.8  1793.7  3401.6           1.9  481.1  37.9
#
#                      SATMTMID
#                 Max Deviation   mean   std
# STABBR RELAFFIL
# AK     0                  NaN    NaN   NaN
#        1                  NaN  503.0   NaN
# AL     0                  1.7  515.8  56.7
#        1                  1.4  485.6  61.4
# AR     0                  2.0  503.6  39.0

# %% [markdown]
# # Customizing aggregating functions with *args and **kwargs

# %%
college = pd.read_csv('data/college.csv')
grouped = college.groupby(['STABBR', 'RELAFFIL'])

# %%
import inspect
inspect.signature(grouped.agg)
# Out:
# <Signature (arg, *args, **kwargs)>

# %% [markdown]
# ## How to do it .....

# %%
def pct_between_1_3k(s):
    return s.between(1000, 3000).mean()

# %%
college.groupby(['STABBR', 'RELAFFIL'])['UGDS'].agg(pct_between_1_3k).head(9)
# Out:
# STABBR  RELAFFIL
# AK      0           0.142857
#         1           0.000000
# AL      0           0.236111
#         1           0.333333
# AR      0           0.279412
#         1           0.111111
# AS      0           1.000000
# AZ      0           0.096774
#         1           0.000000
# Name: UGDS, dtype: float64

# %%
def pct_between(s, low, high):
    return s.between(low, high).mean()

# %%
college.groupby(['STABBR', 'RELAFFIL'])['UGDS'].agg(pct_between, 1000, 10000).head(9)
# Out:
# STABBR  RELAFFIL
# AK      0           0.428571
#         1           0.000000
# AL      0           0.458333
#         1           0.375000
# AR      0           0.397059
#         1           0.166667
# AS      0           1.000000
# AZ      0           0.233871
#         1           0.111111
# Name: UGDS, dtype: float64

# %% [markdown]
# ## How it works .......

# %%
college.groupby(['STABBR', 'RELAFFIL'])['UGDS'].agg(pct_between, high= 10000, low=1000).head(9)
# Out:
# STABBR  RELAFFIL
# AK      0           0.428571
#         1           0.000000
# AL      0           0.458333
#         1           0.375000
# AR      0           0.397059
#         1           0.166667
# AS      0           1.000000
# AZ      0           0.233871
#         1           0.111111
# Name: UGDS, dtype: float64

# %%
college.groupby(['STABBR', 'RELAFFIL'])['UGDS'].agg(pct_between, 1000, high= 10000).head(9)
# Out:
# STABBR  RELAFFIL
# AK      0           0.428571
#         1           0.000000
# AL      0           0.458333
#         1           0.375000
# AR      0           0.397059
#         1           0.166667
# AS      0           1.000000
# AZ      0           0.233871
#         1           0.111111
# Name: UGDS, dtype: float64

# %% [markdown]
# ## There's more .......

# %%
college.groupby(['STABBR', 'RELAFFIL'])['UGDS'].agg(['mean', pct_between], low=1000, high=10000)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-e40bed2a8fdc> in <module>
# ----> 1 college.groupby(['STABBR', 'RELAFFIL'])['UGDS'].agg(['mean', pct_between], low=1000, high=10000)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\generic.py in aggregate(self, func_or_funcs, *args, **kwargs)
#     764             # but not the class list / tuple itself.
#     765             ret = self._aggregate_multiple_funcs(func_or_funcs,
# --> 766                                                  (_level or 0) + 1)
#     767         else:
#     768             cyfunc = self._is_cython_func(func_or_funcs)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\generic.py in _aggregate_multiple_funcs(self, arg, _level)
#     838                 obj._reset_cache()
#     839                 obj._selection = name
# --> 840             results[name] = obj.aggregate(func)
#     841
#     842         if any(isinstance(x, DataFrame) for x in compat.itervalues(results)):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\generic.py in aggregate(self, func_or_funcs, *args, **kwargs)
#     771
#     772             if self.grouper.nkeys > 1:
# --> 773                 return self._python_agg_general(func_or_funcs, *args, **kwargs)
#     774
#     775             try:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in _python_agg_general(self, func, *args, **kwargs)
#     854
#     855         if len(output) == 0:
# --> 856             return self._python_apply_general(f)
#     857
#     858         if self.grouper._filter_empty_groups:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in _python_apply_general(self, f)
#     705     def _python_apply_general(self, f):
#     706         keys, values, mutated = self.grouper.apply(f, self._selected_obj,
# --> 707                                                    self.axis)
#     708
#     709         return self._wrap_applied_output(
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\ops.py in apply(self, f, data, axis)
#     188             # group might be modified
#     189             group_axes = _get_axes(group)
# --> 190             res = f(group)
#     191             if not _is_indexed_like(res, group_axes):
#     192                 mutated = True
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in <lambda>(x)
#     842     def _python_agg_general(self, func, *args, **kwargs):
#     843         func = self._is_builtin_func(func)
# --> 844         f = lambda x: func(x, *args, **kwargs)
#     845
#     846         # iterate through "columns" ex exclusions to populate output dict
#
# TypeError: pct_between() missing 2 required positional arguments: 'low' and 'high'

# %%
def make_agg_func(func, name, *args, **kwargs):
    def wrapper(x):
        return func(x, *args, **kwargs)
    wrapper.__name__ = name
    return wrapper


my_agg1 = make_agg_func(pct_between, 'pct_1_3k', low=1000, high= 3000)
my_agg2 = make_agg_func(pct_between, 'pct_10_30k', 10000, 30000)

# %%
college.groupby(['STABBR', 'RELAFFIL'])['UGDS'].agg(['mean', my_agg1, my_agg2]).head()
# Out:
#                         mean  pct_1_3k  pct_10_30k
# STABBR RELAFFIL
# AK     0         3508.857143  0.142857    0.142857
#        1          123.333333  0.000000    0.000000
# AL     0         3248.774648  0.236111    0.083333
#        1          979.722222  0.333333    0.000000
# AR     0         1793.691176  0.279412    0.014706

# %% [markdown]
# # Examining the groupby object

# %%
college = pd.read_csv('data/college.csv')
grouped = college.groupby(['STABBR', 'RELAFFIL'])
type(grouped)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
print([attr for attr in dir(grouped) if not attr.startswith('_')])
# Out:
# ['CITY', 'CURROPER', 'DISTANCEONLY', 'GRAD_DEBT_MDN_SUPP', 'HBCU', 'INSTNM', 'MD_EARN_WNE_P10', 'MENONLY', 'PCTFLOAN', 'PCTPELL', 'PPTUG_EF', 'RELAFFIL', 'SATMTMID', 'SATVRMID', 'STABBR', 'UG25ABV', 'UGDS', 'UGDS_2MOR', 'UGDS_AIAN', 'UGDS_ASIAN', 'UGDS_BLACK', 'UGDS_HISP', 'UGDS_NHPI', 'UGDS_NRA', 'UGDS_UNKN', 'UGDS_WHITE', 'WOMENONLY', 'agg', 'aggregate', 'all', 'any', 'apply', 'backfill', 'bfill', 'boxplot', 'corr', 'corrwith', 'count', 'cov', 'cumcount', 'cummax', 'cummin', 'cumprod', 'cumsum', 'describe', 'diff', 'dtypes', 'expanding', 'ffill', 'fillna', 'filter', 'first', 'get_group', 'groups', 'head', 'hist', 'idxmax', 'idxmin', 'indices', 'last', 'mad', 'max', 'mean', 'median', 'min', 'ndim', 'ngroup', 'ngroups', 'nth', 'nunique', 'ohlc', 'pad', 'pct_change', 'pipe', 'plot', 'prod', 'quantile', 'rank', 'resample', 'rolling', 'sem', 'shift', 'size', 'skew', 'std', 'sum', 'tail', 'take', 'transform', 'tshift', 'var']

# %%
grouped.ngroups
# Out:
# 112

# %%
groups = list(grouped.groups.keys())
groups[:6]
# Out:
# [('AK', 0), ('AK', 1), ('AL', 0), ('AL', 1), ('AR', 0), ('AR', 1)]

# %%
grouped.get_group(('FL', 1)).head()
# Out:
#                                     INSTNM           CITY STABBR  HBCU  \
# 712         The Baptist College of Florida     Graceville     FL   0.0
# 713                       Barry University          Miami     FL   0.0
# 714  Gooding Institute of Nurse Anesthesia    Panama City     FL   0.0
# 715             Bethune-Cookman University  Daytona Beach     FL   1.0
# 724             Johnson University Florida      Kissimmee     FL   0.0
#
#      MENONLY  WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  ...  \
# 712      0.0        0.0         1     545.0     465.0           0.0  ...
# 713      0.0        0.0         1     470.0     462.0           0.0  ...
# 714      0.0        0.0         1       NaN       NaN           0.0  ...
# 715      0.0        0.0         1     405.0     395.0           0.0  ...
# 724      0.0        0.0         1     480.0     470.0           0.0  ...
#
#      UGDS_2MOR  UGDS_NRA  UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  \
# 712     0.0308    0.0000     0.0507    0.2291         1   0.5878    0.5602
# 713     0.0164    0.0741     0.0841    0.1518         1   0.5045    0.6733
# 714        NaN       NaN        NaN       NaN         0      NaN       NaN
# 715     0.0198    0.0205     0.0190    0.0523         1   0.7758    0.8867
# 724     0.0045    0.0045     0.0136    0.1636         1   0.6689    0.7384
#
#      UG25ABV  MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 712   0.3531            30800               20052
# 713   0.4361            44100               28250
# 714      NaN              NaN   PrivacySuppressed
# 715   0.0647            29400               36250
# 724   0.2185            26300               20199
#
# [5 rows x 27 columns]

# %%
from IPython.display import display

# %%
i = 0
for name, group in grouped:
    print(name)
    display(group.head(2))
    i += 1
    if i == 5:
        break
# Out:
# ('AK', 0)
#                             INSTNM       CITY STABBR  HBCU  MENONLY  \
# 60  University of Alaska Anchorage  Anchorage     AK   0.0      0.0
# 62  University of Alaska Fairbanks  Fairbanks     AK   0.0      0.0
#
#     WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  ...  UGDS_2MOR  \
# 60        0.0         0       NaN       NaN           0.0  ...     0.0980
# 62        0.0         0       NaN       NaN           0.0  ...     0.0401
#
#     UGDS_NRA  UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  \
# 60    0.0181     0.0457    0.4539         1   0.2385    0.2647   0.4386
# 62    0.0110     0.3060    0.3887         1   0.2263    0.2550   0.4519
#
#     MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 60            42500             19449.5
# 62            36200               19355
#
# [2 rows x 27 columns]
# ('AK', 1)
#                        INSTNM       CITY STABBR  HBCU  MENONLY  WOMENONLY  \
# 61       Alaska Bible College     Palmer     AK   0.0      0.0        0.0
# 64  Alaska Pacific University  Anchorage     AK   0.0      0.0        0.0
#
#     RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  ...  UGDS_2MOR  UGDS_NRA  \
# 61         1       NaN       NaN           0.0  ...     0.0370       0.0
# 64         1     555.0     503.0           0.0  ...     0.0945       0.0
#
#     UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  \
# 61     0.0000    0.1481         1   0.3571    0.2857   0.4286
# 64     0.0873    0.3745         1   0.3152    0.5297   0.4910
#
#     MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 61              NaN   PrivacySuppressed
# 64            47000               23250
#
# [2 rows x 27 columns]
# ('AL', 0)
#                                 INSTNM        CITY STABBR  HBCU  MENONLY  \
# 0             Alabama A & M University      Normal     AL   1.0      0.0
# 1  University of Alabama at Birmingham  Birmingham     AL   0.0      0.0
#
#    WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  ...  UGDS_2MOR  \
# 0        0.0         0     424.0     420.0           0.0  ...     0.0000
# 1        0.0         0     570.0     565.0           0.0  ...     0.0368
#
#    UGDS_NRA  UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  \
# 0    0.0059     0.0138    0.0656         1   0.7356    0.8284   0.1049
# 1    0.0179     0.0100    0.2607         1   0.3460    0.5214   0.2422
#
#    MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 0            30300               33888
# 1            39700             21941.5
#
# [2 rows x 27 columns]
# ('AL', 1)
#                          INSTNM        CITY STABBR  HBCU  MENONLY  WOMENONLY  \
# 2            Amridge University  Montgomery     AL   0.0      0.0        0.0
# 10  Birmingham Southern College  Birmingham     AL   0.0      0.0        0.0
#
#     RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  ...  UGDS_2MOR  UGDS_NRA  \
# 2          1       NaN       NaN           1.0  ...     0.0000       0.0
# 10         1     560.0     560.0           0.0  ...     0.0051       0.0
#
#     UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  \
# 2      0.2715    0.4536         1   0.6801    0.7795   0.8540
# 10     0.0051    0.0017         1   0.1920    0.4809   0.0152
#
#     MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 2             40100               23370
# 10            44200               27000
#
# [2 rows x 27 columns]
# ('AR', 0)
#                                           INSTNM         CITY STABBR  HBCU  \
# 128        University of Arkansas at Little Rock  Little Rock     AR   0.0
# 129  University of Arkansas for Medical Sciences  Little Rock     AR   0.0
#
#      MENONLY  WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  ...  \
# 128      0.0        0.0         0     470.0     510.0           0.0  ...
# 129      0.0        0.0         0       NaN       NaN           0.0  ...
#
#      UGDS_2MOR  UGDS_NRA  UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  \
# 128     0.0755    0.0283     0.0003    0.4126         1   0.3941    0.4775
# 129     0.0281    0.0070     0.0169    0.2433         1   0.3944    0.6144
#
#      UG25ABV  MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 128   0.4062            33900               21736
# 129   0.5133            61400               12500
#
# [2 rows x 27 columns]

# %%
grouped.head(2).head(6)
# Out:
#                                  INSTNM        CITY STABBR  HBCU  MENONLY  \
# 0              Alabama A & M University      Normal     AL   1.0      0.0
# 1   University of Alabama at Birmingham  Birmingham     AL   0.0      0.0
# 2                    Amridge University  Montgomery     AL   0.0      0.0
# 10          Birmingham Southern College  Birmingham     AL   0.0      0.0
# 43           Prince Institute-Southeast    Elmhurst     IL   0.0      0.0
# 60       University of Alaska Anchorage   Anchorage     AK   0.0      0.0
#
#     WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  ...  UGDS_2MOR  \
# 0         0.0         0     424.0     420.0           0.0  ...     0.0000
# 1         0.0         0     570.0     565.0           0.0  ...     0.0368
# 2         0.0         1       NaN       NaN           1.0  ...     0.0000
# 10        0.0         1     560.0     560.0           0.0  ...     0.0051
# 43        0.0         0       NaN       NaN           0.0  ...     0.0000
# 60        0.0         0       NaN       NaN           0.0  ...     0.0980
#
#     UGDS_NRA  UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  \
# 0     0.0059     0.0138    0.0656         1   0.7356    0.8284   0.1049
# 1     0.0179     0.0100    0.2607         1   0.3460    0.5214   0.2422
# 2     0.0000     0.2715    0.4536         1   0.6801    0.7795   0.8540
# 10    0.0000     0.0051    0.0017         1   0.1920    0.4809   0.0152
# 43    0.0000     0.0000    0.0000         1   0.7857    0.9375   0.6569
# 60    0.0181     0.0457    0.4539         1   0.2385    0.2647   0.4386
#
#       MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 0               30300               33888
# 1               39700             21941.5
# 2               40100               23370
# 10              44200               27000
# 43  PrivacySuppressed               20992
# 60              42500             19449.5
#
# [6 rows x 27 columns]

# %%
grouped

# %% [markdown]
# ## There's more ......

# %%
grouped.nth([1, -1]).head(8)
# Out:
#                                                   INSTNM        CITY  HBCU  \
# STABBR RELAFFIL
# AK     0                  University of Alaska Fairbanks   Fairbanks   0.0
#        0                               Ilisagvik College      Barrow   0.0
#        1                       Alaska Pacific University   Anchorage   0.0
#        1                        Alaska Christian College    Soldotna   0.0
# AL     0             University of Alabama at Birmingham  Birmingham   0.0
#        0         Alabama College of Osteopathic Medicine      Dothan   0.0
#        1                     Birmingham Southern College  Birmingham   0.0
#        1            Strayer University-Huntsville Campus  Huntsville   NaN
#
#                  MENONLY  WOMENONLY  SATVRMID  SATMTMID  DISTANCEONLY  \
# STABBR RELAFFIL
# AK     0             0.0        0.0       NaN       NaN           0.0
#        0             0.0        0.0       NaN       NaN           0.0
#        1             0.0        0.0     555.0     503.0           0.0
#        1             0.0        0.0       NaN       NaN           0.0
# AL     0             0.0        0.0     570.0     565.0           0.0
#        0             0.0        0.0       NaN       NaN           0.0
#        1             0.0        0.0     560.0     560.0           0.0
#        1             NaN        NaN       NaN       NaN           NaN
#
#                     UGDS  UGDS_WHITE  ...  UGDS_2MOR  UGDS_NRA  UGDS_UNKN  \
# STABBR RELAFFIL                       ...
# AK     0          5536.0      0.4259  ...     0.0401    0.0110     0.3060
#        0           109.0      0.1376  ...     0.0000    0.0183     0.0000
#        1           275.0      0.5309  ...     0.0945    0.0000     0.0873
#        1            68.0      0.0588  ...     0.0147    0.0000     0.1324
# AL     0         11383.0      0.5922  ...     0.0368    0.0179     0.0100
#        0             NaN         NaN  ...        NaN       NaN        NaN
#        1          1180.0      0.7983  ...     0.0051    0.0000     0.0051
#        1             NaN         NaN  ...        NaN       NaN        NaN
#
#                  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  \
# STABBR RELAFFIL
# AK     0           0.3887         1   0.2263    0.2550   0.4519
#        0           0.6239         1   0.1323    0.0000   0.6498
#        1           0.3745         1   0.3152    0.5297   0.4910
#        1           0.0735         1   0.8868    0.6792   0.2264
# AL     0           0.2607         1   0.3460    0.5214   0.2422
#        0              NaN         1      NaN       NaN      NaN
#        1           0.0017         1   0.1920    0.4809   0.0152
#        1              NaN         1      NaN       NaN      NaN
#
#                  MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# STABBR RELAFFIL
# AK     0                   36200               19355
#        0                   24900   PrivacySuppressed
#        1                   47000               23250
#        1                     NaN   PrivacySuppressed
# AL     0                   39700             21941.5
#        0                     NaN   PrivacySuppressed
#        1                   44200               27000
#        1                   49200             36173.5
#
# [8 rows x 25 columns]

# %% [markdown]
# # Filtering for states with a minority majority

# %%
college = pd.read_csv('data/college.csv', index_col = 'INSTNM')
grouped = college.groupby('STABBR')
grouped.ngroups
# Out:
# 59

# %%
# %timeit college['STABBR'].unique()
# Out:
# 490 µs ± 67.9 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
def check_minority(df, threshold):
    minority_pct = 1 - df['UGDS_WHITE']
    total_minority = (df['UGDS'] * minority_pct).sum()
    total_ugds = df['UGDS'].sum()
    total_minority_pct = total_minority / total_ugds
    return total_minority_pct > threshold

# %%
college_filtered = grouped.filter(check_minority, threshold= .5)
college_filtered.head()
# Out:
#                                              CITY STABBR  HBCU  MENONLY  \
# INSTNM
# Everest College-Phoenix                   Phoenix     AZ   0.0      0.0
# Collins College                           Phoenix     AZ   0.0      0.0
# Empire Beauty School-Paradise Valley      Phoenix     AZ   0.0      0.0
# Empire Beauty School-Tucson                Tucson     AZ   0.0      0.0
# Thunderbird School of Global Management  Glendale     AZ   0.0      0.0
#
#                                          WOMENONLY  RELAFFIL  SATVRMID  \
# INSTNM
# Everest College-Phoenix                        0.0         1       NaN
# Collins College                                0.0         0       NaN
# Empire Beauty School-Paradise Valley           0.0         1       NaN
# Empire Beauty School-Tucson                    0.0         0       NaN
# Thunderbird School of Global Management        0.0         0       NaN
#
#                                          SATMTMID  DISTANCEONLY    UGDS  ...  \
# INSTNM                                                                   ...
# Everest College-Phoenix                       NaN           0.0  4102.0  ...
# Collins College                               NaN           0.0    83.0  ...
# Empire Beauty School-Paradise Valley          NaN           0.0    25.0  ...
# Empire Beauty School-Tucson                   NaN           0.0   126.0  ...
# Thunderbird School of Global Management       NaN           0.0     1.0  ...
#
#                                          UGDS_2MOR  UGDS_NRA  UGDS_UNKN  \
# INSTNM
# Everest College-Phoenix                     0.0373       0.0     0.1026
# Collins College                             0.0241       0.0     0.3855
# Empire Beauty School-Paradise Valley        0.0400       0.0     0.0000
# Empire Beauty School-Tucson                 0.0000       0.0     0.0079
# Thunderbird School of Global Management     0.0000       0.0     0.0000
#
#                                          PPTUG_EF  CURROPER  PCTPELL  \
# INSTNM
# Everest College-Phoenix                    0.4749         0   0.8291
# Collins College                            0.3373         0   0.7205
# Empire Beauty School-Paradise Valley       0.1600         0   0.6349
# Empire Beauty School-Tucson                0.2222         1   0.7962
# Thunderbird School of Global Management    1.0000         0   0.0000
#
#                                          PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  \
# INSTNM
# Everest College-Phoenix                    0.7151   0.6700            28600
# Collins College                            0.8228   0.4764            25700
# Empire Beauty School-Paradise Valley       0.5873   0.4651            17800
# Empire Beauty School-Tucson                0.6615   0.4229            18200
# Thunderbird School of Global Management    0.0000   0.0000           118900
#
#                                          GRAD_DEBT_MDN_SUPP
# INSTNM
# Everest College-Phoenix                                9500
# Collins College                                       47000
# Empire Beauty School-Paradise Valley                   9588
# Empire Beauty School-Tucson                            9833
# Thunderbird School of Global Management   PrivacySuppressed
#
# [5 rows x 26 columns]

# %%
college.shape
# Out:
# (7535, 26)

# %%
college_filtered.shape
# Out:
# (3028, 26)

# %%
college_filtered['STABBR'].nunique()
# Out:
# 20

# %% [markdown]
# ## There's more ........

# %%
college_filtered_20 = grouped.filter(check_minority, threshold = .2)
college_filtered_20.shape
# Out:
# (7461, 26)

# %%
college_filtered_20['STABBR'].nunique()
# Out:
# 57

# %%
college_filtered_70 = grouped.filter(check_minority, threshold = .7)
college_filtered_70.shape
# Out:
# (957, 26)

# %%
college_filtered_70['STABBR'].nunique()
# Out:
# 10

# %%
college_filtered_95 = grouped.filter(check_minority, threshold = .95)
college_filtered_95.shape
# Out:
# (156, 26)

# %% [markdown]
# # Transforming through a weight-loss

# %%
weight_loss = pd.read_csv('data/weight_loss.csv')
weight_loss.query('Month == "Jan"')
# Out:
#   Name Month    Week  Weight
# 0  Bob   Jan  Week 1     291
# 1  Amy   Jan  Week 1     197
# 2  Bob   Jan  Week 2     288
# 3  Amy   Jan  Week 2     189
# 4  Bob   Jan  Week 3     283
# 5  Amy   Jan  Week 3     189
# 6  Bob   Jan  Week 4     283
# 7  Amy   Jan  Week 4     190

# %%
def find_perc_loss(s):
    return (s-s.iloc[0])/s.iloc[0]

# %%
bob_jan = weight_loss.query('Name == "Bob" and Month =="Jan"')

# %%
bob_jan
# Out:
#   Name Month    Week  Weight
# 0  Bob   Jan  Week 1     291
# 2  Bob   Jan  Week 2     288
# 4  Bob   Jan  Week 3     283
# 6  Bob   Jan  Week 4     283

# %%
find_perc_loss(bob_jan['Weight'])
# Out:
# 0    0.000000
# 2   -0.010309
# 4   -0.027491
# 6   -0.027491
# Name: Weight, dtype: float64

# %%
pcnt_loss = weight_loss.groupby(['Name', 'Month'])['Weight'].transform(find_perc_loss)
pcnt_loss.head(8)
# Out:
# 0    0.000000
# 1    0.000000
# 2   -0.010309
# 3   -0.040609
# 4   -0.027491
# 5   -0.040609
# 6   -0.027491
# 7   -0.035533
# Name: Weight, dtype: float64

# %%
weight_loss['Perc Weight Loss'] = pcnt_loss.round(3)
weight_loss.query('Name == "Bob" and Month in ["Jan", "Feb"]')
# Out:
#    Name Month    Week  Weight  Perc Weight Loss
# 0   Bob   Jan  Week 1     291             0.000
# 2   Bob   Jan  Week 2     288            -0.010
# 4   Bob   Jan  Week 3     283            -0.027
# 6   Bob   Jan  Week 4     283            -0.027
# 8   Bob   Feb  Week 1     283             0.000
# 10  Bob   Feb  Week 2     275            -0.028
# 12  Bob   Feb  Week 3     268            -0.053
# 14  Bob   Feb  Week 4     268            -0.053

# %%
week4 = weight_loss.query('Week ==  "Week 4"')
week4
# Out:
#    Name Month    Week  Weight  Perc Weight Loss
# 6   Bob   Jan  Week 4     283            -0.027
# 7   Amy   Jan  Week 4     190            -0.036
# 14  Bob   Feb  Week 4     268            -0.053
# 15  Amy   Feb  Week 4     173            -0.089
# 22  Bob   Mar  Week 4     261            -0.026
# 23  Amy   Mar  Week 4     170            -0.017
# 30  Bob   Apr  Week 4     250            -0.042
# 31  Amy   Apr  Week 4     161            -0.053

# %%
winner = week4.pivot(index='Month', columns='Name', values = 'Perc Weight Loss')
winner.style.highlight_min(axis=1)
# Out:
# <style  type="text/css" >
#     #T_89d872ee_56bc_11ea_b345_782bcbb4d4barow0_col0 {
#             background-color:  yellow;
#         }    #T_89d872ee_56bc_11ea_b345_782bcbb4d4barow1_col0 {
#             background-color:  yellow;
#         }    #T_89d872ee_56bc_11ea_b345_782bcbb4d4barow2_col0 {
#             background-color:  yellow;
#         }    #T_89d872ee_56bc_11ea_b345_782bcbb4d4barow3_col1 {
#             background-color:  yellow;
#         }</style><table id="T_89d872ee_56bc_11ea_b345_782bcbb4d4ba" ><thead>    <tr>        <th class="index_name level0" >Name</th>        <th class="col_heading level0 col0" >Amy</th>        <th class="col_heading level0 col1" >Bob</th>    </tr>    <tr>        <th class="index_name level0" >Month</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_89d872ee_56bc_11ea_b345_782bcbb4d4balevel0_row0" class="row_heading level0 row0" >Apr</th>
#                         <td id="T_89d872ee_56bc_11ea_b345_782bcbb4d4barow0_col0" class="data row0 col0" >-0.053</td>
#                         <td id="T_89d872ee_56bc_11ea_b345_782bcbb4d4barow0_col1" class="data row0 col1" >-0.042</td>
#             </tr>
#             <tr>
#                         <th id="T_89d872ee_56bc_11ea_b345_782bcbb4d4balevel0_row1" class="row_heading level0 row1" >Feb</th>
#                         <td id="T_89d872ee_56bc_11ea_b345_782bcbb4d4barow1_col0" class="data row1 col0" >-0.089</td>
#                         <td id="T_89d872ee_56bc_11ea_b345_782bcbb4d4barow1_col1" class="data row1 col1" >-0.053</td>
#             </tr>
#             <tr>
#                         <th id="T_89d872ee_56bc_11ea_b345_782bcbb4d4balevel0_row2" class="row_heading level0 row2" >Jan</th>
#                         <td id="T_89d872ee_56bc_11ea_b345_782bcbb4d4barow2_col0" class="data row2 col0" >-0.036</td>
#                         <td id="T_89d872ee_56bc_11ea_b345_782bcbb4d4barow2_col1" class="data row2 col1" >-0.027</td>
#             </tr>
#             <tr>
#                         <th id="T_89d872ee_56bc_11ea_b345_782bcbb4d4balevel0_row3" class="row_heading level0 row3" >Mar</th>
#                         <td id="T_89d872ee_56bc_11ea_b345_782bcbb4d4barow3_col0" class="data row3 col0" >-0.017</td>
#                         <td id="T_89d872ee_56bc_11ea_b345_782bcbb4d4barow3_col1" class="data row3 col1" >-0.026</td>
#             </tr>
#     </tbody></table>

# %%
winner['Winner'] = np.where(winner['Amy'] < winner['Bob'], 'Amy', 'Bob')
winner.style.highlight_min(axis=1)
# Out:
# <style  type="text/css" >
#     #T_f4b2f06e_56bc_11ea_9dac_782bcbb4d4barow0_col0 {
#             background-color:  yellow;
#         }    #T_f4b2f06e_56bc_11ea_9dac_782bcbb4d4barow1_col0 {
#             background-color:  yellow;
#         }    #T_f4b2f06e_56bc_11ea_9dac_782bcbb4d4barow2_col0 {
#             background-color:  yellow;
#         }    #T_f4b2f06e_56bc_11ea_9dac_782bcbb4d4barow3_col1 {
#             background-color:  yellow;
#         }</style><table id="T_f4b2f06e_56bc_11ea_9dac_782bcbb4d4ba" ><thead>    <tr>        <th class="index_name level0" >Name</th>        <th class="col_heading level0 col0" >Amy</th>        <th class="col_heading level0 col1" >Bob</th>        <th class="col_heading level0 col2" >Winner</th>    </tr>    <tr>        <th class="index_name level0" >Month</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_f4b2f06e_56bc_11ea_9dac_782bcbb4d4balevel0_row0" class="row_heading level0 row0" >Apr</th>
#                         <td id="T_f4b2f06e_56bc_11ea_9dac_782bcbb4d4barow0_col0" class="data row0 col0" >-0.053</td>
#                         <td id="T_f4b2f06e_56bc_11ea_9dac_782bcbb4d4barow0_col1" class="data row0 col1" >-0.042</td>
#                         <td id="T_f4b2f06e_56bc_11ea_9dac_782bcbb4d4barow0_col2" class="data row0 col2" >Amy</td>
#             </tr>
#             <tr>
#                         <th id="T_f4b2f06e_56bc_11ea_9dac_782bcbb4d4balevel0_row1" class="row_heading level0 row1" >Feb</th>
#                         <td id="T_f4b2f06e_56bc_11ea_9dac_782bcbb4d4barow1_col0" class="data row1 col0" >-0.089</td>
#                         <td id="T_f4b2f06e_56bc_11ea_9dac_782bcbb4d4barow1_col1" class="data row1 col1" >-0.053</td>
#                         <td id="T_f4b2f06e_56bc_11ea_9dac_782bcbb4d4barow1_col2" class="data row1 col2" >Amy</td>
#             </tr>
#             <tr>
#                         <th id="T_f4b2f06e_56bc_11ea_9dac_782bcbb4d4balevel0_row2" class="row_heading level0 row2" >Jan</th>
#                         <td id="T_f4b2f06e_56bc_11ea_9dac_782bcbb4d4barow2_col0" class="data row2 col0" >-0.036</td>
#                         <td id="T_f4b2f06e_56bc_11ea_9dac_782bcbb4d4barow2_col1" class="data row2 col1" >-0.027</td>
#                         <td id="T_f4b2f06e_56bc_11ea_9dac_782bcbb4d4barow2_col2" class="data row2 col2" >Amy</td>
#             </tr>
#             <tr>
#                         <th id="T_f4b2f06e_56bc_11ea_9dac_782bcbb4d4balevel0_row3" class="row_heading level0 row3" >Mar</th>
#                         <td id="T_f4b2f06e_56bc_11ea_9dac_782bcbb4d4barow3_col0" class="data row3 col0" >-0.017</td>
#                         <td id="T_f4b2f06e_56bc_11ea_9dac_782bcbb4d4barow3_col1" class="data row3 col1" >-0.026</td>
#                         <td id="T_f4b2f06e_56bc_11ea_9dac_782bcbb4d4barow3_col2" class="data row3 col2" >Bob</td>
#             </tr>
#     </tbody></table>

# %%
winner.Winner.value_counts()
# Out:
# Amy    3
# Bob    1
# Name: Winner, dtype: int64

# %% [markdown]
# ## There's more ......

# %%
week4a = week4.copy()
month_chron = week4a['Month'].unique() # or month.drop_duplicates
month_chron
# Out:
# array(['Jan', 'Feb', 'Mar', 'Apr'], dtype=object)

# %%
week4a['Month'] = pd.Categorical(week4a['Month'], 
                                categories = month_chron,
                                ordered=True)
week4a.pivot(index='Month', columns='Name', values = 'Perc Weight Loss')
# Out:
# Name     Amy    Bob
# Month
# Jan   -0.036 -0.027
# Feb   -0.089 -0.053
# Mar   -0.017 -0.026
# Apr   -0.053 -0.042

# %% [markdown]
# # Calculating weighted mean SAT scores per state with apply

# %%
college = pd.read_csv('data/college.csv')
subset = ['UGDS', 'SATMTMID', 'SATVRMID']
college2 = college.dropna(subset=subset)
college.shape
# Out:
# (7535, 27)

# %%
college2.shape
# Out:
# (1184, 27)

# %%
def weighted_math_average(df):
    weighted_math = df['UGDS'] * df['SATMTMID']
    return int(weighted_math.sum() / df['UGDS'].sum())

# %%
college2.groupby('STABBR').agg(weighted_math_average).head()
# Out:
#         INSTNM  CITY  HBCU  MENONLY  WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  \
# STABBR
# AK         503   503   503      503        503       503       503       503
# AL         536   536   536      536        536       536       536       536
# AR         529   529   529      529        529       529       529       529
# AZ         569   569   569      569        569       569       569       569
# CA         564   564   564      564        564       564       564       564
#
#         DISTANCEONLY  UGDS  ...  UGDS_2MOR  UGDS_NRA  UGDS_UNKN  PPTUG_EF  \
# STABBR                      ...
# AK               503   503  ...        503       503        503       503
# AL               536   536  ...        536       536        536       536
# AR               529   529  ...        529       529        529       529
# AZ               569   569  ...        569       569        569       569
# CA               564   564  ...        564       564        564       564
#
#         CURROPER  PCTPELL  PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  \
# STABBR
# AK           503      503       503      503              503
# AL           536      536       536      536              536
# AR           529      529       529      529              529
# AZ           569      569       569      569              569
# CA           564      564       564      564              564
#
#         GRAD_DEBT_MDN_SUPP
# STABBR
# AK                     503
# AL                     536
# AR                     529
# AZ                     569
# CA                     564
#
# [5 rows x 26 columns]

# %%
college2.groupby('STABBR')['SATMTMID'].agg(weighted_math_average)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\ops.py in agg_series(self, obj, func)
#     589         try:
# --> 590             return self._aggregate_series_fast(obj, func)
#     591         except Exception:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\ops.py in _aggregate_series_fast(self, obj, func)
#     609                                           dummy)
# --> 610         result, counts = grouper.get_result()
#     611         return result, counts
#
# pandas/_libs/reduction.pyx in pandas._libs.reduction.SeriesGrouper.get_result()
#
# pandas/_libs/reduction.pyx in pandas._libs.reduction.SeriesGrouper.get_result()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in <lambda>(x)
#     843         func = self._is_builtin_func(func)
# --> 844         f = lambda x: func(x, *args, **kwargs)
#     845
#
# <ipython-input-5-24f9d83dd6b5> in weighted_math_average(df)
#       1 def weighted_math_average(df):
# ----> 2     weighted_math = df['UGDS'] * df['SATMTMID']
#       3     return int(weighted_math.sum() / df['UGDS'].sum())
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     867         try:
# --> 868             result = self.index.get_value(self, key)
#     869
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4374             return self._engine.get_value(s, k,
# -> 4375                                           tz=getattr(series.dtype, 'tz', None))
#    4376         except KeyError as e1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'UGDS'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\generic.py in aggregate(self, func_or_funcs, *args, **kwargs)
#     775             try:
# --> 776                 return self._python_agg_general(func_or_funcs, *args, **kwargs)
#     777             except Exception:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in _python_agg_general(self, func, *args, **kwargs)
#     849             try:
# --> 850                 result, counts = self.grouper.agg_series(obj, f)
#     851                 output[name] = self._try_cast(result, obj, numeric_only=True)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\ops.py in agg_series(self, obj, func)
#     591         except Exception:
# --> 592             return self._aggregate_series_pure_python(obj, func)
#     593
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\ops.py in _aggregate_series_pure_python(self, obj, func)
#     622         for label, group in splitter:
# --> 623             res = func(group)
#     624             if result is None:
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\groupby.py in <lambda>(x)
#     843         func = self._is_builtin_func(func)
# --> 844         f = lambda x: func(x, *args, **kwargs)
#     845
#
# <ipython-input-5-24f9d83dd6b5> in weighted_math_average(df)
#       1 def weighted_math_average(df):
# ----> 2     weighted_math = df['UGDS'] * df['SATMTMID']
#       3     return int(weighted_math.sum() / df['UGDS'].sum())
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     867         try:
# --> 868             result = self.index.get_value(self, key)
#     869
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4374             return self._engine.get_value(s, k,
# -> 4375                                           tz=getattr(series.dtype, 'tz', None))
#    4376         except KeyError as e1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'UGDS'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-c0a37b2b29e0> in <module>
# ----> 1 college2.groupby('STABBR')['SATMTMID'].agg(weighted_math_average)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\generic.py in aggregate(self, func_or_funcs, *args, **kwargs)
#     776                 return self._python_agg_general(func_or_funcs, *args, **kwargs)
#     777             except Exception:
# --> 778                 result = self._aggregate_named(func_or_funcs, *args, **kwargs)
#     779
#     780             index = Index(sorted(result), name=self.grouper.names[0])
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\groupby\generic.py in _aggregate_named(self, func, *args, **kwargs)
#     905         for name, group in self:
#     906             group.name = name
# --> 907             output = func(group, *args, **kwargs)
#     908             if isinstance(output, (Series, Index, np.ndarray)):
#     909                 raise Exception('Must produce aggregated value')
#
# <ipython-input-5-24f9d83dd6b5> in weighted_math_average(df)
#       1 def weighted_math_average(df):
# ----> 2     weighted_math = df['UGDS'] * df['SATMTMID']
#       3     return int(weighted_math.sum() / df['UGDS'].sum())
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     866         key = com.apply_if_callable(key, self)
#     867         try:
# --> 868             result = self.index.get_value(self, key)
#     869
#     870             if not is_scalar(result):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4373         try:
#    4374             return self._engine.get_value(s, k,
# -> 4375                                           tz=getattr(series.dtype, 'tz', None))
#    4376         except KeyError as e1:
#    4377             if len(self) > 0 and (self.holds_integer() or self.is_boolean()):
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'UGDS'

# %%
from collections import OrderedDict
def weighted_average(df):
            data = OrderedDict()
            weight_m = df['UGDS'] * df['SATMTMID']
            weight_v = df['UGDS'] * df['SATVRMID']
            wm_avg = weight_m.sum() / df['UGDS'].sum()
            
            wv_avg = weight_v.sum() / df['UGDS'].sum()
            
            data['weighted_math_avg'] = int(wm_avg)
            data['weighted_verbal_avg'] = int(wv_avg)
            data['math_avg'] = int(df['SATMTMID'].mean())
            data['verbal_avg'] = int(df['SATVRMID'].mean())
            data['count'] = len(df)
            return pd.Series(data, dtype='int')

college2.groupby('STABBR').apply(weighted_average).head(10)
# Out:
#         weighted_math_avg  weighted_verbal_avg  math_avg  verbal_avg  count
# STABBR
# AK                    503                  555       503         555      1
# AL                    536                  533       504         508     21
# AR                    529                  504       515         491     16
# AZ                    569                  557       536         538      6
# CA                    564                  539       562         549     72
# CO                    553                  547       540         537     14
# CT                    545                  533       522         517     14
# DC                    621                  623       588         589      6
# DE                    569                  553       495         486      3
# FL                    565                  565       521         529     38

# %% [markdown]
# ## There's more .......

# %%
from scipy.stats import gmean, hmean

def calculate_means(df):
    
    df_means = pd.DataFrame(index=['Arithmetic', 'Weighted', 'Geometric', 'Harmonic'])
    cols = ['SATMTMID', 'SATVRMID']
    
    for col in cols:
        arithmetic = df[col].mean()
        weighted = np.average(df[col], weights=df['UGDS'])
        geometric = gmean(df[col])
        harmonic = hmean(df[col])
        df_means[col] = [arithmetic, weighted, geometric, harmonic]
                                 
    df_means['count'] = len(df)
    return df_means.astype(int)
                                 

college2.groupby('STABBR').filter(lambda x: len(x) !=1).groupby('STABBR').apply(calculate_means).head(10)
# Out:
#                    SATMTMID  SATVRMID  count
# STABBR
# AL     Arithmetic       504       508     21
#        Weighted         536       533     21
#        Geometric        500       505     21
#        Harmonic         497       502     21
# AR     Arithmetic       515       491     16
#        Weighted         529       504     16
#        Geometric        514       489     16
#        Harmonic         513       487     16
# AZ     Arithmetic       536       538      6
#        Weighted         569       557      6

# %% [markdown]
# # Grouping by continuous variables

# %%
flights = pd.read_csv('data/flights.csv')
flights.head()
# Out:
#    MONTH  DAY  WEEKDAY AIRLINE ORG_AIR DEST_AIR  SCHED_DEP  DEP_DELAY  \
# 0      1    1        4      WN     LAX      SLC       1625       58.0
# 1      1    1        4      UA     DEN      IAD        823        7.0
# 2      1    1        4      MQ     DFW      VPS       1305       36.0
# 3      1    1        4      AA     DFW      DCA       1555        7.0
# 4      1    1        4      WN     LAX      MCI       1720       48.0
#
#    AIR_TIME  DIST  SCHED_ARR  ARR_DELAY  DIVERTED  CANCELLED
# 0      94.0   590       1905       65.0         0          0
# 1     154.0  1452       1333      -13.0         0          0
# 2      85.0   641       1453       35.0         0          0
# 3     126.0  1192       1935       -7.0         0          0
# 4     166.0  1363       2225       39.0         0          0

# %%
flights.DIST.hasnans
# Out:
# False

# %%
flights.dropna(subset=['DIST']).shape
# Out:
# (58492, 14)

# %%
bins = [-np.inf, 200, 500, 1000, 2000, np.inf]
cuts = pd.cut(flights['DIST'], bins=bins)
cuts.head()
# Out:
# 0     (500.0, 1000.0]
# 1    (1000.0, 2000.0]
# 2     (500.0, 1000.0]
# 3    (1000.0, 2000.0]
# 4    (1000.0, 2000.0]
# Name: DIST, dtype: category
# Categories (5, interval[float64]): [(-inf, 200.0] < (200.0, 500.0] < (500.0, 1000.0] < (1000.0, 2000.0] < (2000.0, inf]]

# %%
cuts.value_counts()
# Out:
# (500.0, 1000.0]     20659
# (200.0, 500.0]      15874
# (1000.0, 2000.0]    14186
# (2000.0, inf]        4054
# (-inf, 200.0]        3719
# Name: DIST, dtype: int64

# %%
flights.groupby(cuts)['AIRLINE'].value_counts(normalize=True).round(3).head(15)
# Out:
# DIST            AIRLINE
# (-inf, 200.0]   OO         0.326
#                 EV         0.289
#                 MQ         0.211
#                 DL         0.086
#                 AA         0.052
#                 UA         0.027
#                 WN         0.009
# (200.0, 500.0]  WN         0.194
#                 DL         0.189
#                 OO         0.159
#                 EV         0.156
#                 MQ         0.100
#                 AA         0.071
#                 UA         0.062
#                 VX         0.028
# Name: AIRLINE, dtype: float64

# %% [markdown]
# ## How it works ........

# %%
flights.groupby(cuts)['AIRLINE'].value_counts(normalize=True)
# Out:
# DIST              AIRLINE
# (-inf, 200.0]     OO         0.325625
#                   EV         0.289325
#                   MQ         0.210809
#                   DL         0.086045
#                   AA         0.052165
#                   UA         0.027427
#                   WN         0.008604
# (200.0, 500.0]    WN         0.193902
#                   DL         0.188736
#                   OO         0.158687
#                   EV         0.156293
#                   MQ         0.100164
#                   AA         0.071375
#                   UA         0.062051
#                   VX         0.028222
#                   US         0.016001
#                   NK         0.011843
#                   B6         0.006867
#                   F9         0.004914
#                   AS         0.000945
# (500.0, 1000.0]   DL         0.205625
#                   AA         0.143908
#                   WN         0.138196
#                   UA         0.131129
#                   OO         0.106443
#                   EV         0.100683
#                   MQ         0.051213
#                   F9         0.038192
#                   NK         0.029527
#                   US         0.025316
#                   AS         0.023234
#                   VX         0.003582
#                   B6         0.002953
# (1000.0, 2000.0]  AA         0.263781
#                   UA         0.199070
#                   DL         0.165092
#                   WN         0.159664
#                   OO         0.046454
#                   NK         0.045115
#                   US         0.040462
#                   F9         0.030664
#                   AS         0.015931
#                   EV         0.015579
#                   VX         0.012125
#                   B6         0.003313
#                   MQ         0.002749
# (2000.0, inf]     UA         0.289097
#                   AA         0.211643
#                   DL         0.171436
#                   B6         0.080414
#                   VX         0.073754
#                   US         0.065121
#                   WN         0.046374
#                   HA         0.027627
#                   NK         0.019240
#                   AS         0.011593
#                   F9         0.003700
# Name: AIRLINE, dtype: float64

# %% [markdown]
# ## There's more .......

# %%
flights.groupby(cuts)['AIR_TIME'].quantile(q=[.25, .5, .75]).div(60).round(2)
# Out:
# DIST
# (-inf, 200.0]     0.25    0.43
#                   0.50    0.50
#                   0.75    0.57
# (200.0, 500.0]    0.25    0.77
#                   0.50    0.92
#                   0.75    1.05
# (500.0, 1000.0]   0.25    1.43
#                   0.50    1.65
#                   0.75    1.92
# (1000.0, 2000.0]  0.25    2.50
#                   0.50    2.93
#                   0.75    3.40
# (2000.0, inf]     0.25    4.30
#                   0.50    4.70
#                   0.75    5.03
# Name: AIR_TIME, dtype: float64

# %%
labels = ['Under an Hour', '1 Hour', '1-2 Hours', '2-4 Hours', '4+ Hours']
cuts2 = pd.cut(flights['DIST'], bins=bins, labels=labels)
flights.groupby(cuts2)['AIRLINE'].value_counts(normalize=True).round(3).unstack().style.highlight_max(axis=1)
# Out:
# <style  type="text/css" >
#     #T_3125c286_5779_11ea_be03_782bcbb4d4barow0_col9 {
#             background-color:  yellow;
#         }    #T_3125c286_5779_11ea_be03_782bcbb4d4barow1_col13 {
#             background-color:  yellow;
#         }    #T_3125c286_5779_11ea_be03_782bcbb4d4barow2_col3 {
#             background-color:  yellow;
#         }    #T_3125c286_5779_11ea_be03_782bcbb4d4barow3_col0 {
#             background-color:  yellow;
#         }    #T_3125c286_5779_11ea_be03_782bcbb4d4barow4_col10 {
#             background-color:  yellow;
#         }</style><table id="T_3125c286_5779_11ea_be03_782bcbb4d4ba" ><thead>    <tr>        <th class="index_name level0" >AIRLINE</th>        <th class="col_heading level0 col0" >AA</th>        <th class="col_heading level0 col1" >AS</th>        <th class="col_heading level0 col2" >B6</th>        <th class="col_heading level0 col3" >DL</th>        <th class="col_heading level0 col4" >EV</th>        <th class="col_heading level0 col5" >F9</th>        <th class="col_heading level0 col6" >HA</th>        <th class="col_heading level0 col7" >MQ</th>        <th class="col_heading level0 col8" >NK</th>        <th class="col_heading level0 col9" >OO</th>        <th class="col_heading level0 col10" >UA</th>        <th class="col_heading level0 col11" >US</th>        <th class="col_heading level0 col12" >VX</th>        <th class="col_heading level0 col13" >WN</th>    </tr>    <tr>        <th class="index_name level0" >DIST</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_3125c286_5779_11ea_be03_782bcbb4d4balevel0_row0" class="row_heading level0 row0" >Under an Hour</th>
#                         <td id="T_3125c286_5779_11ea_be03_782bcbb4d4barow0_col0" class="data row0 col0" >0.052</td>
#                         <td id="T_3125c286_5779_11ea_be03_782bcbb4d4barow0_col1" class="data row0 col1" >nan</td>
#                         <td id="T_3125c286_5779_11ea_be03_782bcbb4d4barow0_col2" class="data row0 col2" >nan</td>
#                         <td id="T_3125c286_5779_11ea_be03_782bcbb4d4barow0_col3" class="data row0 col3" >0.086</td>
#                         <td id="T_3125c286_5779_11ea_be03_782bcbb4d4barow0_col4" class="data row0 col4" >0.289</td>
#                         <td id="T_3125c286_5779_11ea_be03_782bcbb4d4barow0_col5" class="data row0 col5" >nan</td>
#                         <td id="T_3125c286_5779_11ea_be03_782bcbb4d4barow0_col6" class="data row0 col6" >nan</td>
#                         <td id="T_3125c286_5779_11ea_be03_782bcbb4d4barow0_col7" class="data row0 col7" >0.211</td>
#                         <td id="T_3125c286_5779_11ea_be03_782bcbb4d4barow0_col8" class="data row0 col8" >nan</td>
#                         <td id="T_3125c286_5779_11ea_be03_782bcbb4d4barow0_col9" class="data row0 col9" >0.326</td>
#                         <td id="T_3125c286_5779_11ea_be03_782bcbb4d4barow0_col10" class="data row0 col10" >0.027</td>
#                         <td id="T_3125c286_5779_11ea_be03_782bcbb4d4barow0_col11" class="data row0 col11" >nan</td>
#                         <td id="T_3125c286_5779_11ea_be03_782bcbb4d4barow0_col12" class="data row0 col12" >nan</td>
#                         <td id="T_3125c286_5779_11ea_be03_782bcbb4d4barow0_col13" class="data row0 col13" >0.009</td>
#             </tr>
#             <tr>
#                         <th id="T_3125c286_5779_11ea_be03_782bcbb4d4balevel0_row1" class="row_heading level0 row1" >1 Hour</th>
#                         <td id="T_3125c286_5779_11ea_be03_782bcbb4d4barow1_col0" class="data row1 col0" >0.071</td>
#                         <td id="T_3125c286_5779_11ea_be03_782bcbb4d4barow1_col1" class="data row1 col1" >0.001</td>
#                         <td id="T_3125c286_5779_11ea_be03_782bcbb4d4barow1_col2" class="data row1 col2" >0.007</td>
#                         <td id="T_3125c286_5779_11ea_be03_782bcbb4d4barow1_col3" class="data row1 col3" >0.189</td>
#                         <td id="T_3125c286_5779_11ea_be03_782bcbb4d4barow1_col4" class="data row1 col4" >0.156</td>
#                         <td id="T_3125c286_5779_11ea_be03_782bcbb4d4barow1_col5" class="data row1 col5" >0.005</td>
#                         <td id="T_3125c286_5779_11ea_be03_782bcbb4d4barow1_col6" class="data row1 col6" >nan</td>
#                         <td id="T_3125c286_5779_11ea_be03_782bcbb4d4barow1_col7" class="data row1 col7" >0.1</td>
#                         <td id="T_3125c286_5779_11ea_be03_782bcbb4d4barow1_col8" class="data row1 col8" >0.012</td>
#                         <td id="T_3125c286_5779_11ea_be03_782bcbb4d4barow1_col9" class="data row1 col9" >0.159</td>
#                         <td id="T_3125c286_5779_11ea_be03_782bcbb4d4barow1_col10" class="data row1 col10" >0.062</td>
#                         <td id="T_3125c286_5779_11ea_be03_782bcbb4d4barow1_col11" class="data row1 col11" >0.016</td>
#                         <td id="T_3125c286_5779_11ea_be03_782bcbb4d4barow1_col12" class="data row1 col12" >0.028</td>
#                         <td id="T_3125c286_5779_11ea_be03_782bcbb4d4barow1_col13" class="data row1 col13" >0.194</td>
#             </tr>
#             <tr>
#                         <th id="T_3125c286_5779_11ea_be03_782bcbb4d4balevel0_row2" class="row_heading level0 row2" >1-2 Hours</th>
#                         <td id="T_3125c286_5779_11ea_be03_782bcbb4d4barow2_col0" class="data row2 col0" >0.144</td>
#                         <td id="T_3125c286_5779_11ea_be03_782bcbb4d4barow2_col1" class="data row2 col1" >0.023</td>
#                         <td id="T_3125c286_5779_11ea_be03_782bcbb4d4barow2_col2" class="data row2 col2" >0.003</td>
#                         <td id="T_3125c286_5779_11ea_be03_782bcbb4d4barow2_col3" class="data row2 col3" >0.206</td>
#                         <td id="T_3125c286_5779_11ea_be03_782bcbb4d4barow2_col4" class="data row2 col4" >0.101</td>
#                         <td id="T_3125c286_5779_11ea_be03_782bcbb4d4barow2_col5" class="data row2 col5" >0.038</td>
#                         <td id="T_3125c286_5779_11ea_be03_782bcbb4d4barow2_col6" class="data row2 col6" >nan</td>
#                         <td id="T_3125c286_5779_11ea_be03_782bcbb4d4barow2_col7" class="data row2 col7" >0.051</td>
#                         <td id="T_3125c286_5779_11ea_be03_782bcbb4d4barow2_col8" class="data row2 col8" >0.03</td>
#                         <td id="T_3125c286_5779_11ea_be03_782bcbb4d4barow2_col9" class="data row2 col9" >0.106</td>
#                         <td id="T_3125c286_5779_11ea_be03_782bcbb4d4barow2_col10" class="data row2 col10" >0.131</td>
#                         <td id="T_3125c286_5779_11ea_be03_782bcbb4d4barow2_col11" class="data row2 col11" >0.025</td>
#                         <td id="T_3125c286_5779_11ea_be03_782bcbb4d4barow2_col12" class="data row2 col12" >0.004</td>
#                         <td id="T_3125c286_5779_11ea_be03_782bcbb4d4barow2_col13" class="data row2 col13" >0.138</td>
#             </tr>
#             <tr>
#                         <th id="T_3125c286_5779_11ea_be03_782bcbb4d4balevel0_row3" class="row_heading level0 row3" >2-4 Hours</th>
#                         <td id="T_3125c286_5779_11ea_be03_782bcbb4d4barow3_col0" class="data row3 col0" >0.264</td>
#                         <td id="T_3125c286_5779_11ea_be03_782bcbb4d4barow3_col1" class="data row3 col1" >0.016</td>
#                         <td id="T_3125c286_5779_11ea_be03_782bcbb4d4barow3_col2" class="data row3 col2" >0.003</td>
#                         <td id="T_3125c286_5779_11ea_be03_782bcbb4d4barow3_col3" class="data row3 col3" >0.165</td>
#                         <td id="T_3125c286_5779_11ea_be03_782bcbb4d4bar
