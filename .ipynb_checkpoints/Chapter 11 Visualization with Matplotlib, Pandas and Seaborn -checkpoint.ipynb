# %% [markdown]
# # Chapter 11: Visualization with Matplotlib, Pandas, and Seaborn
#
# ## Recipes
#
# * [Getting started with matplotlib](#Getting-started-with-matplotlib)
# * [Visualizing data with matplotlib](#Visualizing-data-with-matplotlib)
# * [Plotting basics with pandas](#Plotting-basics-with-pandas)
# * [Visualizing the flights dataset](#Visualizing-the-flights-dataset)
# * [Stacking area charts to discover emerging trends](#Stacking-area-charts-to-discover-emerging-trends)
# * [Understanding the differences between seaborn and pandas](#Understanding-the-differences-between-seaborn-and-pandas)
# * [Doing multivariate analysis with seaborn grids](#Doing-multivariate-analysis-with-seaborn-grids)
# * [Uncovering Simpson's paradox in the diamonds dataset with seaborn](#Uncovering-Simpson's-paradox-in-the-diamonds-dataset-with-seaborn)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# # Getting started with Matplotlib

# %% [markdown]
# ## Getting Ready

# %%
x = [-3, 5, 7]
y = [10, 2, 5]

plt.figure(figsize=(15,3))
plt.plot(x, y)
plt.xlim(0, 10)
plt.ylim(-3, 8)
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.title('Line Plot')
plt.suptitle('Figure Title', size=20, y=1.03)
# Out:
# Text(0.5, 1.03, 'Figure Title')

# %%
fig, ax = plt.subplots(figsize=(15, 3))
ax.plot(x, y)
ax.set_xlim(0, 10)
ax.set_ylim(-3, 8)
ax.set_xlabel('X Axis')
ax.set_ylabel('Y Axis')
ax.set_title('Line Plot')
fig.suptitle('Figure Title', size=20, y=1.03)
# Out:
# Text(0.5, 1.03, 'Figure Title')

# %%
fig, ax = plt.subplots(nrows=1, ncols=1)

# %%
type(fig)
# Out:
# matplotlib.figure.Figure

# %%
type(ax)
# Out:
# matplotlib.axes._subplots.AxesSubplot

# %%
fig.get_size_inches()
# Out:
# array([6., 4.])

# %%
fig.set_size_inches(14, 4)

# %%
fig

# %%
fig.axes

# %%
fig.axes[0] is ax
# Out:
# True

# %%
fig.set_facecolor('.9')
ax.set_facecolor('.7')
fig

# %%
spines = ax.spines
spines
# Out:
# OrderedDict([('left', <matplotlib.spines.Spine at 0x20797ee48>),
#              ('right', <matplotlib.spines.Spine at 0x207e71be0>),
#              ('bottom', <matplotlib.spines.Spine at 0x207e71780>),
#              ('top', <matplotlib.spines.Spine at 0x207e710b8>)])

# %%
spine_left = spines['left']
spine_left.set_position(('outward', -100))
spine_left.set_linewidth(5)

spine_bottom = spines['bottom']
spine_bottom.set_visible(False)
fig

# %%
ax.xaxis.grid(True, which='major', linewidth=2, color='black', linestyle='--')
ax.xaxis.set_ticks([.2, .4, .55, .93])
ax.xaxis.set_label_text('X Axis', family='Verdana', fontsize=15)

ax.set_ylabel('Y Axis', family='Calibri', fontsize=20)
ax.set_yticks([.1, .9])
ax.set_yticklabels(['point 1', 'point 9'], rotation=45)
fig

# %%
ax.xaxis.properties()
# Out:
# {'agg_filter': None,
#  'alpha': None,
#  'animated': False,
#  'children': [Text(0.5, 22.200000000000003, 'X Axis'),
#   Text(1, 23.200000000000003, ''),
#   <matplotlib.axis.XTick at 0x207ad9710>,
#   <matplotlib.axis.XTick at 0x207ad9048>,
#   <matplotlib.axis.XTick at 0x20842f0f0>,
#   <matplotlib.axis.XTick at 0x207ae04e0>],
#  'clip_box': <matplotlib.transforms.TransformedBbox at 0x207adfeb8>,
#  'clip_on': True,
#  'clip_path': None,
#  'contains': None,
#  'data_interval': array([ inf, -inf]),
#  'figure': <Figure size 1008x288 with 1 Axes>,
#  'gid': None,
#  'gridlines': <a list of 4 Line2D gridline objects>,
#  'in_layout': True,
#  'label': Text(0.5, 22.200000000000003, 'X Axis'),
#  'label_position': 'bottom',
#  'label_text': 'X Axis',
#  'major_formatter': <matplotlib.ticker.ScalarFormatter at 0x208420c50>,
#  'major_locator': <matplotlib.ticker.FixedLocator at 0x207b0e780>,
#  'major_ticks': [<matplotlib.axis.XTick at 0x207ad9710>,
#   <matplotlib.axis.XTick at 0x207ad9048>,
#   <matplotlib.axis.XTick at 0x20842f0f0>,
#   <matplotlib.axis.XTick at 0x207ae04e0>],
#  'majorticklabels': <a list of 4 Text major ticklabel objects>,
#  'majorticklines': <a list of 8 Line2D ticklines objects>,
#  'majorticklocs': array([0.2 , 0.4 , 0.55, 0.93]),
#  'minor_formatter': <matplotlib.ticker.NullFormatter at 0x208420908>,
#  'minor_locator': <matplotlib.ticker.NullLocator at 0x208415400>,
#  'minor_ticks': [],
#  'minorticklabels': <a list of 0 Text minor ticklabel objects>,
#  'minorticklines': <a list of 0 Line2D ticklines objects>,
#  'minorticklocs': [],
#  'minpos': inf,
#  'offset_text': Text(1, 23.200000000000003, ''),
#  'path_effects': [],
#  'picker': None,
#  'pickradius': 15,
#  'rasterized': None,
#  'scale': 'linear',
#  'sketch_params': None,
#  'smart_bounds': False,
#  'snap': None,
#  'tick_padding': 3.5,
#  'tick_space': 26,
#  'ticklabels': <a list of 4 Text major ticklabel objects>,
#  'ticklines': <a list of 8 Line2D ticklines objects>,
#  'ticklocs': array([0.2 , 0.4 , 0.55, 0.93]),
#  'ticks_direction': array(['out', 'out', 'out', 'out'], dtype='<U3'),
#  'ticks_position': 'bottom',
#  'transform': <matplotlib.transforms.IdentityTransform at 0x207e4b128>,
#  'transformed_clip_path_and_affine': (None, None),
#  'units': None,
#  'url': None,
#  'view_interval': array([0., 1.]),
#  'visible': True,
#  'zorder': 1.5}

# %%
movie = pd.read_csv('data/movie.csv')

# %%
med_budget = movie.groupby('title_year')['budget'].median()/1e6
med_budget_roll = med_budget.rolling(5, min_periods=1).mean()
med_budget_roll.tail()
# Out:
# title_year
# 2012.0    20.893
# 2013.0    19.893
# 2014.0    19.100
# 2015.0    17.980
# 2016.0    17.780
# Name: budget, dtype: float64

# %%
years = med_budget_roll.index.values

# %%
years[-5:]
# Out:
# array([2012., 2013., 2014., 2015., 2016.])

# %%
budget = med_budget_roll.values
budget[-5:]
# Out:
# array([20.893, 19.893, 19.1  , 17.98 , 17.78 ])

# %%
fig, ax = plt.subplots(figsize=(14, 4), linewidth=5, edgecolor='.5')
ax.plot(years, budget, linestyle='--', linewidth=3, color='.2', label='All Movies')
text_kwargs = dict(fontsize=20, family='cursive')
ax.set_title('Median Movie Budget', **text_kwargs)
ax.set_ylabel('Millions of Dollars', **text_kwargs)
# Out:
# Text(0, 0.5, 'Millions of Dollars')
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\font_manager.py:1241: UserWarning: findfont: Font family ['cursive'] not found. Falling back to DejaVu Sans.
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
movie_count = movie.groupby('title_year')['budget'].count()
movie_count.tail()
# Out:
# title_year
# 2012.0    191
# 2013.0    208
# 2014.0    221
# 2015.0    192
# 2016.0     86
# Name: budget, dtype: int64

# %%
ct = movie_count.values
ct_norm = ct / ct.max() * budget.max()

fifth_year = (years % 5 == 0) & (years >= 1970)
years_5 = years[fifth_year]
ct_5 = ct[fifth_year]
ct_norm_5 = ct_norm[fifth_year]

ax.bar(years_5, ct_norm_5, 3, facecolor='.5', alpha=.3, label='Movies per Year')
ax.set_xlim(1968, 2017)
for x, y, v in zip(years_5, ct_norm, ct_5):
    ax.text(x, y + .5, str(v), ha='center')
ax.legend()
fig

# %% [markdown]
# ##     How it works

# %%
plot_objects = plt.subplots()

# %%
type(plot_objects)
# Out:
# tuple

# %%
fig = plot_objects[0]
ax = plot_objects[1]

# %%
plot_objects = plt.subplots(2, 4, figsize=(14, 4))

# %%
plot_objects[1]
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000000020873F9E8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000002087B31D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000002043D8400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000204401630>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000000020442A860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000000204452A90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000000020447CCC0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000002044A6EB8>]],
#       dtype=object)

# %%
fig.get_axes() ==  fig.axes
# Out:
# True

# %%
fig, ax = plt.subplots()

# %%
fig.axes == fig.get_axes()
# Out:
# True

# %%
ax.xaxis == ax.get_xaxis()
# Out:
# True

# %%
ax.yaxis == ax.get_yaxis()
# Out:
# True

# %% [markdown]
# # Visualizing data with Matplotlib

# %%
movie = pd.read_csv('data/movie.csv')
med_budget = movie.groupby('title_year')['budget'].median() /1e6
med_budget_roll = med_budget.rolling(5, min_periods=1).mean()
med_budget_roll.tail()
# Out:
# title_year
# 2012.0    20.893
# 2013.0    19.893
# 2014.0    19.100
# 2015.0    17.980
# 2016.0    17.780
# Name: budget, dtype: float64

# %%
years = med_budget_roll.index.values
years[-5:]
# Out:
# array([2012., 2013., 2014., 2015., 2016.])

# %%
fig, ax = plt.subplots(figsize=(14, 4), linewidth=5, edgecolor='.5')
ax.plot(years, budget, linestyle='--', linewidth=3, color='.2', label='All Movies')
text_kwargs = dict(fontsize=20, family='cursive')
ax.set_title('Median Movie Budget', **text_kwargs)
ax.set_ylabel('Millions of Dollars', **text_kwargs)
# Out:
# Text(0, 0.5, 'Millions of Dollars')

# %%
movie_count = movie.groupby('title_year')['budget'].count()
movie_count.tail()
# Out:
# title_year
# 2012.0    191
# 2013.0    208
# 2014.0    221
# 2015.0    192
# 2016.0     86
# Name: budget, dtype: int64

# %%
ct= movie_count.values
ct_norm = ct / ct.max() * budget.max()

fifth_year = (years % 5 == 0) & (years >= 1970)
years_5 = years[fifth_year]
ct_5 = ct[fifth_year]
ct_norm_5 = ct_norm[fifth_year]

ax.bar(years_5, ct_norm_5, 3, facecolor='.5', alpha=.3, label='Movies per Year' )
ax.set_xlim(1968, 2017)
for x, y ,v in zip(years_5, ct_norm_5, ct_5):
    ax.text(x, y + .5, str(v), ha='center')
ax.legend()
fig

# %%
x1 = zip(years_5, ct_norm_5, ct_5)

# %%
print(list(x1))
# Out:
# [(1970.0, 1.4497737556561086, 12), (1975.0, 0.7248868778280543, 6), (1980.0, 2.53710407239819, 21), (1985.0, 3.2619909502262443, 27), (1990.0, 3.382805429864253, 28), (1995.0, 8.094570135746606, 67), (2000.0, 19.692760180995474, 163), (2005.0, 23.921266968325792, 198), (2010.0, 23.196380090497737, 192), (2015.0, 23.196380090497737, 192)]

# %%
ct_5
# Out:
# array([ 12,   6,  21,  27,  28,  67, 163, 198, 192, 192], dtype=int64)

# %%
years_5
# Out:
# array([1970., 1975., 1980., 1985., 1990., 1995., 2000., 2005., 2010.,
#        2015.])

# %%
top10 = movie.sort_values('budget', ascending=False).groupby('title_year')['budget'] \
        .apply(lambda x: x.iloc[:10].median() / 1e6)

top10_roll = top10.rolling(5, min_periods=1).mean()
top10_roll.tail()
# Out:
# title_year
# 2012.0    192.9
# 2013.0    195.9
# 2014.0    191.7
# 2015.0    186.8
# 2016.0    189.1
# Name: budget, dtype: float64

# %%
fig2, ax_array = plt.subplots(2, 1, figsize=(14, 6), sharex=True)
ax1 = ax_array[0]
ax2 = ax_array[1]

ax1.plot(years, budget, linestyle='--', linewidth=3, color='.2', label='All Movies')
ax1.bar(years_5, ct_norm_5, 3, facecolor='.5', alpha=.3, label='Movies per Year')
ax1.legend(loc='upper left')
ax1.set_xlim(1968, 2017)
plt.setp(ax1.get_xticklines(), visible=False)

for x, y, v in zip(years_5, ct_norm_5, ct_5):
    ax1.text(x, y + .5, str(v), ha='center')
    

ax2.plot(years, top10_roll.values, color='.2', label='Top 10 Movies')
ax2.legend(loc='upper left')

fig2.tight_layout()
fig2.suptitle('Median Movie Budget', y=1.02, **text_kwargs)
fig2.text(0, .6, 'Million of Dollars', rotation='vertical', ha='center', **text_kwargs)


import os
path = os.path.expanduser('~/Desktop/movie_budget.png')
fig2.savefig(path, bbox_inches='tight')

# %% [markdown]
# ## How it works ......

# %%
med_budget_roll.tail()
# Out:
# title_year
# 2012.0    20.893
# 2013.0    19.893
# 2014.0    19.100
# 2015.0    17.980
# 2016.0    17.780
# Name: budget, dtype: float64

# %%
med_budget.loc[2012:2016].mean()
# Out:
# 17.78

# %%
med_budget.loc[2011:2015].mean()
# Out:
# 17.98

# %%
med_budget.loc[2010:2014].mean()
# Out:
# 19.1
